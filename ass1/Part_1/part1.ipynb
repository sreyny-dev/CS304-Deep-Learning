# %% [markdown]
# Part I: The Perceptron

# %% [markdown]
# Task 1: Generate Dataset

# %%
import numpy as np

mean1 = [1,2]
cov1 = [[0.5, 0], [0, 0.5]]
mean2 = [7,8]
cov2 = [[0.5, 0], [0, 0.5]]

# dataset 1
data1_train = np.random.multivariate_normal(mean1, cov1, 80)
data1_test = np.random.multivariate_normal(mean1, cov1, 20)

# dataset 2
data2_train = np.random.multivariate_normal(mean2, cov2, 80)
data2_test = np.random.multivariate_normal(mean2, cov2, 20)

# Combining the dataset 1 and dataset 2
X_train = np.vstack([data1_train, data2_train]) # training set: 160 points 
X_test = np.vstack([data1_test, data2_test]) # test set: 40 points

# Creating labels for the dataset
y_train = np.array([-1]*80 + [1]*80)
y_test = np.array([-1]*20 + [1]*20)

# Shuffling the training dataset
shuffle_train = np.random.permutation(160)
X_train_shuffled = X_train[shuffle_train]
y_train_shuffled = y_train[shuffle_train]

print("Training dataset shape:", X_train_shuffled.shape)
print("Test dataset shape:", X_test.shape)
# Out:
# Training dataset shape: (160, 2)
# Test dataset shape: (40, 2)

# %% [markdown]
# Plot the Dataset

# %%
import matplotlib.pyplot as plt

# Plotting the training dataset
plt.figure(figsize=(8, 6))
plt.scatter(X_train_shuffled[y_train_shuffled == -1][:, 0], X_train_shuffled[y_train_shuffled == -1][:, 1], color='blue', label='class -1')
plt.scatter(X_train_shuffled[y_train_shuffled == 1][:, 0], X_train_shuffled[y_train_shuffled == 1][:, 1], color='red', label='class 1')
plt.title('Training Dataset')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# Plotting the test dataset
plt.figure(figsize=(8, 6))
plt.scatter(X_test[y_test == -1][:, 0], X_test[y_test == -1][:, 1], color='blue', label='class -1')
plt.scatter(X_test[y_test == 1][:, 0], X_test[y_test == 1][:, 1], color='red', label='class 1')
plt.title('Test Dataset')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %% [markdown]
# Task 2: Implement perceptron.py

# %%
from perceptron import Perceptron

learning_rate = 0.01
epochs = 100

n_inputs = X_train_shuffled.shape[1]

print('n_inputs: ' + str(n_inputs))

perceptron_model = Perceptron(n_inputs, max_epochs=epochs, learning_rate=learning_rate)
# Out:
# n_inputs: 2

# %% [markdown]
# Task 3: Train the model

# %%
perceptron_model.train(X_train_shuffled, y_train_shuffled)
# Out:
# Epoch 0: Training Accuracy: 0.50, Loss: 80
# Epoch 1: Training Accuracy: 0.50, Loss: 80
# Epoch 2: Training Accuracy: 0.51, Loss: 80
# Epoch 3: Training Accuracy: 0.52, Loss: 79
# Epoch 4: Training Accuracy: 0.61, Loss: 77
# Epoch 5: Training Accuracy: 0.97, Loss: 62
# Epoch 6: Training Accuracy: 0.99, Loss: 4
# Epoch 7: Training Accuracy: 0.99, Loss: 2
# Epoch 8: Training Accuracy: 0.99, Loss: 2
# Epoch 9: Training Accuracy: 0.99, Loss: 2
# Epoch 10: Training Accuracy: 0.99, Loss: 1
# Epoch 11: Training Accuracy: 0.99, Loss: 1
# Epoch 12: Training Accuracy: 0.99, Loss: 2
# Epoch 13: Training Accuracy: 0.99, Loss: 1
# Epoch 14: Training Accuracy: 0.99, Loss: 1
# Epoch 15: Training Accuracy: 0.99, Loss: 1
# Epoch 16: Training Accuracy: 0.99, Loss: 1
# Epoch 17: Training Accuracy: 0.99, Loss: 2
# Epoch 18: Training Accuracy: 0.99, Loss: 1
# Epoch 19: Training Accuracy: 0.99, Loss: 1
# Epoch 20: Training Accuracy: 0.99, Loss: 1
# Epoch 21: Training Accuracy: 0.99, Loss: 1
# Epoch 22: Training Accuracy: 0.99, Loss: 2
# Epoch 23: Training Accuracy: 0.99, Loss: 1
# Epoch 24: Training Accuracy: 0.99, Loss: 1
# Epoch 25: Training Accuracy: 0.99, Loss: 1
# Epoch 26: Training Accuracy: 0.99, Loss: 1
# Epoch 27: Training Accuracy: 0.99, Loss: 2
# Epoch 28: Training Accuracy: 0.99, Loss: 1
# Epoch 29: Training Accuracy: 0.99, Loss: 1
# Epoch 30: Training Accuracy: 0.99, Loss: 1
# Epoch 31: Training Accuracy: 0.99, Loss: 1
# Epoch 32: Training Accuracy: 0.99, Loss: 1
# Epoch 33: Training Accuracy: 0.99, Loss: 1
# Epoch 34: Training Accuracy: 0.99, Loss: 1
# Epoch 35: Training Accuracy: 1.00, Loss: 1
# Epoch 36: Training Accuracy: 1.00, Loss: 0
# Epoch 37: Training Accuracy: 1.00, Loss: 0
# Epoch 38: Training Accuracy: 1.00, Loss: 0
# Epoch 39: Training Accuracy: 1.00, Loss: 0
# Epoch 40: Training Accuracy: 1.00, Loss: 0
# Epoch 41: Training Accuracy: 1.00, Loss: 0
# Epoch 42: Training Accuracy: 1.00, Loss: 0
# Epoch 43: Training Accuracy: 1.00, Loss: 0
# Epoch 44: Training Accuracy: 1.00, Loss: 0
# Epoch 45: Training Accuracy: 1.00, Loss: 0
# Epoch 46: Training Accuracy: 1.00, Loss: 0
# Epoch 47: Training Accuracy: 1.00, Loss: 0
# Epoch 48: Training Accuracy: 1.00, Loss: 0
# Epoch 49: Training Accuracy: 1.00, Loss: 0
# Epoch 50: Training Accuracy: 1.00, Loss: 0
# Epoch 51: Training Accuracy: 1.00, Loss: 0
# Epoch 52: Training Accuracy: 1.00, Loss: 0
# Epoch 53: Training Accuracy: 1.00, Loss: 0
# Epoch 54: Training Accuracy: 1.00, Loss: 0
# Epoch 55: Training Accuracy: 1.00, Loss: 0
# Epoch 56: Training Accuracy: 1.00, Loss: 0
# Epoch 57: Training Accuracy: 1.00, Loss: 0
# Epoch 58: Training Accuracy: 1.00, Loss: 0
# Epoch 59: Training Accuracy: 1.00, Loss: 0
# Epoch 60: Training Accuracy: 1.00, Loss: 0
# Epoch 61: Training Accuracy: 1.00, Loss: 0
# Epoch 62: Training Accuracy: 1.00, Loss: 0
# Epoch 63: Training Accuracy: 1.00, Loss: 0
# Epoch 64: Training Accuracy: 1.00, Loss: 0
# Epoch 65: Training Accuracy: 1.00, Loss: 0
# Epoch 66: Training Accuracy: 1.00, Loss: 0
# Epoch 67: Training Accuracy: 1.00, Loss: 0
# Epoch 68: Training Accuracy: 1.00, Loss: 0
# Epoch 69: Training Accuracy: 1.00, Loss: 0
# Epoch 70: Training Accuracy: 1.00, Loss: 0
# Epoch 71: Training Accuracy: 1.00, Loss: 0
# Epoch 72: Training Accuracy: 1.00, Loss: 0
# Epoch 73: Training Accuracy: 1.00, Loss: 0
# Epoch 74: Training Accuracy: 1.00, Loss: 0
# Epoch 75: Training Accuracy: 1.00, Loss: 0
# Epoch 76: Training Accuracy: 1.00, Loss: 0
# Epoch 77: Training Accuracy: 1.00, Loss: 0
# Epoch 78: Training Accuracy: 1.00, Loss: 0
# Epoch 79: Training Accuracy: 1.00, Loss: 0
# Epoch 80: Training Accuracy: 1.00, Loss: 0
# Epoch 81: Training Accuracy: 1.00, Loss: 0
# Epoch 82: Training Accuracy: 1.00, Loss: 0
# Epoch 83: Training Accuracy: 1.00, Loss: 0
# Epoch 84: Training Accuracy: 1.00, Loss: 0
# Epoch 85: Training Accuracy: 1.00, Loss: 0
# Epoch 86: Training Accuracy: 1.00, Loss: 0
# Epoch 87: Training Accuracy: 1.00, Loss: 0
# Epoch 88: Training Accuracy: 1.00, Loss: 0
# Epoch 89: Training Accuracy: 1.00, Loss: 0
# Epoch 90: Training Accuracy: 1.00, Loss: 0
# Epoch 91: Training Accuracy: 1.00, Loss: 0
# Epoch 92: Training Accuracy: 1.00, Loss: 0
# Epoch 93: Training Accuracy: 1.00, Loss: 0
# Epoch 94: Training Accuracy: 1.00, Loss: 0
# Epoch 95: Training Accuracy: 1.00, Loss: 0
# Epoch 96: Training Accuracy: 1.00, Loss: 0
# Epoch 97: Training Accuracy: 1.00, Loss: 0
# Epoch 98: Training Accuracy: 1.00, Loss: 0
# Epoch 99: Training Accuracy: 1.00, Loss: 0

# %% [markdown]
# Task 4: Test the test dataset

# %%
y_pred = np.array([perceptron_model.forward(x) for x in X_test])

# %% [markdown]
# Task 5: Evaluate the accuracy

# %%
# TRAINING SET ACCURACY
y_pred_train = np.array([perceptron_model.forward(x) for x in X_train_shuffled])

accuracy_train = np.mean(y_pred_train == y_train_shuffled)
print(f'Training Accuracy: {accuracy_train:.2f}')

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_train_shuffled, y_pred_train))
print(confusion_matrix(y_train_shuffled, y_pred_train))

# plot training accuracy 
import matplotlib.pyplot as plt

plt.plot(perceptron_model.training_accuracy)
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.title('Training Performance Over Epochs')
plt.show()


# TEST SET ACCURACY
accuracy = np.mean(y_pred == y_test)

print(f'Test set accuracy: {accuracy:.2f}')

from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Training Accuracy: 1.00
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160
#
# [[80  0]
#  [ 0 80]]
# Test set accuracy: 1.00
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
#
# [[20  0]
#  [ 0 20]]

# %%
import matplotlib.pyplot as plt
import numpy as np

n = [1, 2, 4, 8, 16, 32, 64, 128, 256]
time = [0.349355, 0.183921,  0.100202, 0.073695 , 0.055597 , 0.064719,  0.109430,0.360149, 1.151803 ]

x = np.linspace(0,2,100)
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
ax.plot(n, time)
ax.set_xlabel('Number of Processes')  # Add an x-label to the axes.
ax.set_ylabel('Execution Time (seconds)')  # Add a y-label to the axes.
ax.set_title("Execution Time vs. Numer of Processes")  # Add a title to the axes.
plt.grid(True)
ax.legend()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8456\719131854.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
speed_up = [1.021090, 2.223329,3.722794, 5.863897, 7.414271, 14.577683, 14.325417,9.098634, 6.680106 ]

x2 = np.linspace(0,2,100)
fig2, ax2 = plt.subplots(figsize=(6, 4), layout='constrained')
ax2.plot(n, speed_up)
ax2.set_xlabel('Number of Processes')  # Add an x-label to the axes.
ax2.set_ylabel('Speed Up')  # Add a y-label to the axes.
ax2.set_title("Speed Up vs. Numer of Processes")  # Add a title to the axes.
plt.grid(True)
ax2.legend()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8456\4217870564.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()
